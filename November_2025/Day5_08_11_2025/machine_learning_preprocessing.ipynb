# %%
import pandas as pd

# %%
df = pd.read_csv("diamonds.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
specific_data = df[['carat', 'cut', 'color']]
print(specific_data)
# Out:
#        carat        cut color
# 0       0.23      Ideal     E
# 1       0.21    Premium     E
# 2       0.23       Good     E
# 3       0.29    Premium     I
# 4       0.31       Good     J
# ...      ...        ...   ...
# 53935   0.72      Ideal     D
# 53936   0.72       Good     D
# 53937   0.70  Very Good     D
# 53938   0.86    Premium     H
# 53939   0.75      Ideal     D
#
# [53940 rows x 3 columns]

# %%
specific_row = df[5:50]
print(specific_row)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 5            6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6            7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7            8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8            9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9           10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10          11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 11          12   0.23      Ideal     J     VS1   62.8   56.0    340  3.93
# 12          13   0.22    Premium     F     SI1   60.4   61.0    342  3.88
# 13          14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 14          15   0.20    Premium     E     SI2   60.2   62.0    345  3.79
# 15          16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 16          17   0.30      Ideal     I     SI2   62.0   54.0    348  4.31
# ...

# %%
row_fetching_with_iloc = df.iloc[5:50]
#print(row_fetching_with_iloc)
row_fetching_with_iloc_col = df.iloc[5:50,2]
#print(row_fetching_with_iloc_col)
row_fetching_with_iloc_col_list = df.iloc[5:50,[2,4]]
print(row_fetching_with_iloc_col_list)
# Out:
#           cut clarity
# 5   Very Good    VVS2
# 6   Very Good    VVS1
# 7   Very Good     SI1
# 8        Fair     VS2
# 9   Very Good     VS1
# 10       Good     SI1
# 11      Ideal     VS1
# 12    Premium     SI1
# 13      Ideal     SI2
# 14    Premium     SI2
# 15    Premium      I1
# 16      Ideal     SI2
# 17       Good     SI1
# 18       Good     SI1
# 19  Very Good     SI1
# 20       Good     SI2
# 21  Very Good     VS2
# 22  Very Good     VS1
# 23  Very Good     SI1
# 24  Very Good     SI1
# 25  Very Good    VVS2
# 26    Premium     VS1
# 27  Very Good     VS2
# 28  Very Good     VS2
# 29  Very Good     VS1
# 30  Very Good     VS1
# 31  Very Good     VS1
# 32  Very Good     VS1
# 33  Very Good     VS1
# 34  Very Good     VS1
# 35       Good     VS1
# 36       Good     VS1
# 37       Good     SI1
# 38  Very Good     VS2
# 39      Ideal     SI2
# 40      Ideal     SI2
# 41      Ideal     SI1
# 42       Good     VS2
# 43       Good     VS1
# 44       Good     SI2
# ...

# %%
row_fetching_with_loc = df.loc[5:50]
#print(row_fetching_with_iloc)
row_fetching_with_loc_col = df.loc[5:50,'carat']
print(row_fetching_with_iloc_col)
# Out:
# 5     Very Good
# 6     Very Good
# 7     Very Good
# 8          Fair
# 9     Very Good
# 10         Good
# 11        Ideal
# 12      Premium
# 13        Ideal
# 14      Premium
# 15      Premium
# 16        Ideal
# 17         Good
# 18         Good
# 19    Very Good
# 20         Good
# 21    Very Good
# 22    Very Good
# 23    Very Good
# 24    Very Good
# 25    Very Good
# 26      Premium
# 27    Very Good
# 28    Very Good
# 29    Very Good
# 30    Very Good
# 31    Very Good
# 32    Very Good
# 33    Very Good
# 34    Very Good
# 35         Good
# 36         Good
# 37         Good
# 38    Very Good
# 39        Ideal
# 40        Ideal
# 41        Ideal
# 42         Good
# 43         Good
# 44         Good
# 45      Premium
# 46    Very Good
# 47         Good
# 48    Very Good
# 49    Very Good
# Name: cut, dtype: object
