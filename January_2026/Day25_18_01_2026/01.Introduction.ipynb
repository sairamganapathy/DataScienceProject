# %%
import pandas

# %%
df = pandas.read_csv("AirQualityUCI.csv", sep = ";", decimal = ",")

# %%
df = df.iloc[ : , 0:14]

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH
# 0          1268.0  13.6  48.9
# 1           972.0  13.3  47.7
# 2          1074.0  11.9  54.0
# 3          1203.0  11.0  60.0
# 4          1110.0  11.2  59.6
# ...           ...   ...   ...
# 9466          NaN   NaN   NaN
# 9467          NaN   NaN   NaN
# 9468          NaN   NaN   NaN
# 9469          NaN   NaN   NaN
# 9470          NaN   NaN   NaN
#
# [9471 rows x 14 columns]

# %%
len(df)
# Out:
# 9471

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH
# 0  13.6  48.9
# 1  13.3  47.7
# 2  11.9  54.0
# 3  11.0  60.0
# 4  11.2  59.6

# %%
#Dropping NaN(Not-a-Number)
df = df[df['Date'].notnull()]

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH
# 0          1268.0  13.6  48.9
# 1           972.0  13.3  47.7
# 2          1074.0  11.9  54.0
# 3          1203.0  11.0  60.0
# 4          1110.0  11.2  59.6
# ...           ...   ...   ...
# 9352       1729.0  21.9  29.3
# 9353       1269.0  24.3  23.7
# 9354       1092.0  26.9  18.3
# 9355        770.0  28.3  13.5
# 9356        816.0  28.5  13.1
#
# [9357 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# dtype: int64

# %%
df['DateTime'] = (df.Date) + ' ' + (df.Time)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23804\2617385575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DateTime'] = (df.Date) + ' ' + (df.Time)

# %%
df['DateTime']
# Out:
# 0      2004-03-10 18:00:00
# 1      2004-03-10 19:00:00
# 2      2004-03-10 20:00:00
# 3      2004-03-10 21:00:00
# 4      2004-03-10 22:00:00
# 5      2004-03-10 23:00:00
# 6      2004-03-11 00:00:00
# 7      2004-03-11 01:00:00
# 8      2004-03-11 02:00:00
# 9      2004-03-11 03:00:00
# 10     2004-03-11 04:00:00
# 11     2004-03-11 05:00:00
# 12     2004-03-11 06:00:00
# 13     2004-03-11 07:00:00
# 14     2004-03-11 08:00:00
# 15     2004-03-11 09:00:00
# 16     2004-03-11 10:00:00
# 17     2004-03-11 11:00:00
# 18     2004-03-11 12:00:00
# 19     2004-03-11 13:00:00
# 20     2004-03-11 14:00:00
# 21     2004-03-11 15:00:00
# 22     2004-03-11 16:00:00
# 23     2004-03-11 17:00:00
# 24     2004-03-11 18:00:00
# 25     2004-03-11 19:00:00
# 26     2004-03-11 20:00:00
# 27     2004-03-11 21:00:00
# 28     2004-03-11 22:00:00
# 29     2004-03-11 23:00:00
#                ...
# 9327   2005-04-03 09:00:00
# 9328   2005-04-03 10:00:00
# 9329   2005-04-03 11:00:00
# 9330   2005-04-03 12:00:00
# 9331   2005-04-03 13:00:00
# 9332   2005-04-03 14:00:00
# 9333   2005-04-03 15:00:00
# 9334   2005-04-03 16:00:00
# 9335   2005-04-03 17:00:00
# 9336   2005-04-03 18:00:00
# 9337   2005-04-03 19:00:00
# 9338   2005-04-03 20:00:00
# 9339   2005-04-03 21:00:00
# 9340   2005-04-03 22:00:00
# 9341   2005-04-03 23:00:00
# 9342   2005-04-04 00:00:00
# 9343   2005-04-04 01:00:00
# 9344   2005-04-04 02:00:00
# 9345   2005-04-04 03:00:00
# 9346   2005-04-04 04:00:00
# 9347   2005-04-04 05:00:00
# 9348   2005-04-04 06:00:00
# 9349   2005-04-04 07:00:00
# 9350   2005-04-04 08:00:00
# 9351   2005-04-04 09:00:00
# 9352   2005-04-04 10:00:00
# 9353   2005-04-04 11:00:00
# 9354   2005-04-04 12:00:00
# 9355   2005-04-04 13:00:00
# 9356   2005-04-04 14:00:00
# Name: DateTime, Length: 9357, dtype: datetime64[ns]

# %%
print(type(df.DateTime[0]))
# Out:
# <class 'str'>

# %%
import datetime

# %%
df.DateTime = df.DateTime.apply(lambda x: datetime.datetime.strptime(x, '%d/%m/%Y %H.%M.%S'))
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23804\3200307902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DateTime = df.DateTime.apply(lambda x: datetime.datetime.strptime(x, '%d/%m/%Y %H.%M.%S'))

# %%
df.DateTime
# Out:
# 0      2004-03-10 18:00:00
# 1      2004-03-10 19:00:00
# 2      2004-03-10 20:00:00
# 3      2004-03-10 21:00:00
# 4      2004-03-10 22:00:00
#                ...
# 9352   2005-04-04 10:00:00
# 9353   2005-04-04 11:00:00
# 9354   2005-04-04 12:00:00
# 9355   2005-04-04 13:00:00
# 9356   2005-04-04 14:00:00
# Name: DateTime, Length: 9357, dtype: datetime64[ns]

# %%
print (type(df.DateTime[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df.index = df.DateTime

# %%
df.index
# type(df.index)
# Out:
# DatetimeIndex(['2004-03-10 18:00:00', '2004-03-10 19:00:00',
#                '2004-03-10 20:00:00', '2004-03-10 21:00:00',
#                '2004-03-10 22:00:00', '2004-03-10 23:00:00',
#                '2004-03-11 00:00:00', '2004-03-11 01:00:00',
#                '2004-03-11 02:00:00', '2004-03-11 03:00:00',
#                ...
#                '2005-04-04 05:00:00', '2005-04-04 06:00:00',
#                '2005-04-04 07:00:00', '2005-04-04 08:00:00',
#                '2005-04-04 09:00:00', '2005-04-04 10:00:00',
#                '2005-04-04 11:00:00', '2005-04-04 12:00:00',
#                '2005-04-04 13:00:00', '2005-04-04 14:00:00'],
#               dtype='datetime64[ns]', name='DateTime', length=9357, freq=None)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['T'])
# Out:
# /home/angicia/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(df['C6H6(GT)'])

# %%
plt.boxplot(df[['T','C6H6(GT)']].values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb697f61710>,
#   <matplotlib.lines.Line2D at 0x7fb697f61a58>,
#   <matplotlib.lines.Line2D at 0x7fb697eeeeb8>,
#   <matplotlib.lines.Line2D at 0x7fb697eeef98>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb697f61da0>,
#   <matplotlib.lines.Line2D at 0x7fb697f61e80>,
#   <matplotlib.lines.Line2D at 0x7fb697ef9588>,
#   <matplotlib.lines.Line2D at 0x7fb697ef98d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb697f61358>,
#   <matplotlib.lines.Line2D at 0x7fb697eeeb70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb697eee470>,
#   <matplotlib.lines.Line2D at 0x7fb697ef9c18>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb697eee7b8>,
#   <matplotlib.lines.Line2D at 0x7fb697ef9f60>],
#  'means': []}
